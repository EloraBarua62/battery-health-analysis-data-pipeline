# %%
# %sql
SHOW CATALOGS;

# %% [markdown]
# Create Schema on existing catalog

# %%
# %sql
USE CATALOG batteryhealthdatabricks;

CREATE SCHEMA IF NOT EXISTS batteryhealthdatabricks.silver;
CREATE SCHEMA IF NOT EXISTS batteryhealthdatabricks.gold;

SHOW SCHEMAS;
